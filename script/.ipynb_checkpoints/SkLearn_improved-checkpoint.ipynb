# %%
import geopandas
import scipy as sp
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os
import seaborn as sns
from bokeh.io import output_notebook
from bokeh.layouts import gridplot,row,column
from bokeh.plotting import figure,show

# %%
terrain = sns.color_palette(palette='terrain',n_colors=10)
plasma = sns.color_palette(palette='plasma',n_colors=10)
rainbow = sns.color_palette(palette='rainbow',n_colors=6)

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
os.chdir('/Users/Edward/Documents/LandPermitAnalysis/data/')

# %%
data = pd.read_csv('Land_Use_Permits.csv').copy()
data.head(5)
# Out:
#     PermitNum           PermitClass PermitClassMapped   PermitTypeMapped  \
# 0  3027306-LU            Commercial   Non-Residential  Master Use Permit
# 1  3003127-LU           Multifamily       Residential  Master Use Permit
# 2  3016564-LU           Multifamily       Residential  Master Use Permit
# 3  3028041-LU           Multifamily       Residential  Master Use Permit
# 4  3004979-LU  Single Family/Duplex       Residential  Master Use Permit
#
#   PermitTypeDesc                                        Description  \
# 0            NaN  [EDG Pre-sub] landlord work to modify and upgr...
# 1            NaN  CANCELLED - DECISION EXPIRED 12/28/09 JH.  Lan...
# 2            NaN  Land Use Application to subdivide one developm...
# 3            NaN  Land Use Application to subdivide one developm...
# 4            NaN  Shoreline substantial development to allow a t...
#
#    HousingUnits  HousingUnitsRemoved  HousingUnitsAdded  EstProjectCost  ...  \
# ...

# %%
data = data.dropna(axis=0, subset=['Latitude'])

# %%
PermitID = []
for row in data['PermitNum']:
    temp = row[0:7]
    PermitID.append(temp)
    
data['PermitNum'] = PermitID

# %%
sum(data.PermitClass.isnull())
# Out:
# 0

# %%
data.PermitClass =data.PermitClass.replace(np.nan, 'unknown', regex=True)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(data['PermitClass'])
PermitClass_label = le.transform(data['PermitClass'])
data['PermitClass_Label'] = PermitClass_label

# %%
Commercial = 0
Multifamily = 0
SingleFamily = 0
Unknown = 0
Institutional = 0 
VacantLand = 0
Industrial = 0

for item in data.PermitClass:
    if item == 'Commercial':
        Commercial += 1
    elif item == 'Multifamily':
        Multifamily += 1
    elif item == 'Single Family/Duplex':
        SingleFamily += 1
    elif item == 'unknow':
        Unknown += 1
    elif item == 'Institutional':
        Institutional += 1
    elif item == 'Vacant Land':
        VacantLand += 1
    else:
        Industrial += 1

x = ['Commercial', 'Multifamily', 'Single Family', 'Unknown', 'Institutional', 'Vacant Land', 'Industrial']
y = [Commercial, Multifamily, SingleFamily, Unknown, Institutional, VacantLand, Industrial]

# %%
plt.bar(x,y, align='center', alpha=0.5)
plt.rcParams["figure.figsize"] =[9,9]
plt.title("Permit Number and Permit Classes")
plt.xlabel("Permit Class")
plt.ylabel("Permit Number")
plt.grid()
plt.show()

# %%
X=pd.concat([data['Latitude'],data['Longitude']],axis=1)

# %%
y=data['PermitClass_Label']

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
models = pd.DataFrame(index = ['train_mse', 'test_mse'], columns = ['KNN', 'Bagging', 'RandomForest', 'Boosting'])

# %%
knn = KNeighborsRegressor(n_neighbors = 20, weights = 'distance', metric = 'euclidean', n_jobs = -1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=45)
neigh = KNeighborsClassifier(n_neighbors=9)
neigh.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=9, p=2,
#            weights='uniform')

# %%
data.PermitClassMapped = data.PermitClassMapped.replace(np.nan,'unknow', regex=True)
# Out:
# array(['Non-Residential', 'Residential', 'unknow'], dtype=object)

# %%
medLat
# Out:
# 0        47.611197
# 10       47.688435
# 11       47.727359
# 14       47.626738
# 20       47.721445
# 23       47.659420
# 29       47.570560
# 37       47.667228
# 40       47.588638
# 41       47.610303
# 44       47.697986
# 49       47.698377
# 52       47.536777
# 55       47.669744
# 57       47.632074
# 61       47.625630
# 70       47.523826
# 75       47.705582
# 89       47.553283
# 91       47.668953
# 98       47.613028
# 99       47.617585
# 102      47.667252
# 103      47.572695
# 106      47.612353
# 111      47.688916
# 113      47.651610
# 117      47.634269
# 125      47.607077
# 134      47.570910
#            ...
# 15972    47.610659
# 15977    47.580809
# 15979    47.608836
# 15996    47.640332
# 16003    47.665847
# 16014    47.614669
# 16016    47.626269
# 16017    47.617705
# 16026    47.619989
# 16029    47.577540
# 16030    47.647999
# 16035    47.614164
# 16038    47.619511
# 16059    47.518606
# 16063    47.503961
# 16080    47.585216
# ...

# %%
plot = figure(title="interest level based on geography")

# %%
lowLat=data['Latitude'][data['PermitClassMapped']=='low']
lowLong=data['Longitude'][data['PermitClassMapped']=='low']
medLat=data['Latitude'][data['PermitClassMapped']=='med']
medLong=data['Longitude'][data['PermitClassMapped']=='med']
highLat=data['Latitude'][data['PermitClassMapped']=='high']
highLong=data['Longitude'][data['PermitClassMapped']=='high']
plot.circle(lowLong,lowLat,size=5,color=terrain.as_hex()[1],fill_alpha=0.1,line_alpha=0.1,legend='low')
plot.circle(medLong,medLat,size=8,color=plasma.as_hex()[9],fill_alpha=0.1,line_alpha=0.1,legend='med')
plot.circle(highLong,highLat,size=10,color=plasma.as_hex()[5],fill_alpha=0.1,line_alpha=0.1,legend='high')
show(plot, notebook_handle=True)
# Out:
#   <div class="bk-root" id="c1f2dc47-18ca-4187-9fcf-6d25cb1f8541" data-root-id="1863"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[67]</strong>&gt;</code></p>

# %%
#https://www.kaggle.com/xchiron/rental-list-knn-on-lat-long-data

# %%
import geopandas

# %%
import pandas as pd

# %%
import numpy as ny

# %%
import matplotlib

# %%
import plotly
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-6361d2547ebc> in <module>()
# ----> 1 import plotly
#
# ModuleNotFoundError: No module named 'plotly'

# %%
from mpl_toolkits.basemap import Basemap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-d9467465a3b6> in <module>()
# ----> 1 from mpl_toolkits.basemap import Basemap
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
data = pd.read_csv('C:/Users/LXB19/Documents/LandUsePermitAnalysis/LandPermitAnalysis/data/Land_Use_Permits.csv')

# %%
data.head
# Out:
# <bound method NDFrame.head of         PermitNum           PermitClass PermitClassMapped  \
# 0      3027306-LU            Commercial   Non-Residential
# 1      3003127-LU           Multifamily       Residential
# 2      3016564-LU           Multifamily       Residential
# 3      3028041-LU           Multifamily       Residential
# 4      3004979-LU  Single Family/Duplex       Residential
# 5      3018602-LU                   NaN               NaN
# 6      3008462-LU           Multifamily       Residential
# 7      3008682-LU                   NaN               NaN
# 8      3003799-LU           Multifamily       Residential
# 9      3013754-LU           Multifamily       Residential
# 10     3021641-LU            Commercial   Non-Residential
# 11     3018445-LU            Commercial   Non-Residential
# 12     3026919-LU           Multifamily       Residential
# 13     3021649-LU  Single Family/Duplex       Residential
# 14     3011700-LU            Commercial   Non-Residential
# ...

# %%
district=geopandas.read_file('C:/Users/LXB19/Documents/LandUsePermitAnalysis/LandPermitAnalysis/data/Council_Districts/Council_Districts.shp')

# %%
district.plot()
